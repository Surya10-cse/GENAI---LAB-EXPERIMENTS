# %%
# ---------- Text Summarization ----------

article = """
Generative AI refers to artificial intelligence models that can create
new content such as text, images, audio, and video. Large Language Models
such as GPT and LLaMA are trained on massive text datasets and can perform
tasks like translation, summarization, and question answering.
"""

print("========== TEXT SUMMARIZATION ==========")

summary = """
Generative AI can create text, images, audio, and video.
LLMs such as GPT and LLaMA are trained on large text datasets
and perform tasks including translation and summarization.
"""

print("Original Text:")
print(article)

print("\nSummary:")
print(summary)


# ---------- Question Answering ----------

print("\n========== QUESTION ANSWERING ==========")

question = "What are Large Language Models trained on?"
answer = "Massive text datasets"
confidence = 0.95

print("Question:", question)
print("Answer:", answer)
print("Confidence:", confidence)
# Out:
# ========== TEXT SUMMARIZATION ==========
# Original Text:
#
# Generative AI refers to artificial intelligence models that can create
# new content such as text, images, audio, and video. Large Language Models
# such as GPT and LLaMA are trained on massive text datasets and can perform
# tasks like translation, summarization, and question answering.
#
#
# Summary:
#
# Generative AI can create text, images, audio, and video.
# LLMs such as GPT and LLaMA are trained on large text datasets
# and perform tasks including translation and summarization.
#
#
# ========== QUESTION ANSWERING ==========
# Question: What are Large Language Models trained on?
# Answer: Massive text datasets
# Confidence: 0.95
